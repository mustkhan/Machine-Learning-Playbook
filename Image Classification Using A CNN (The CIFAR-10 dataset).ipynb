# %% [markdown]
# <a href="https://colab.research.google.com/github/MustafaKhan670093/Machine-Learning-Playbook/blob/master/Image%20Classification%20Using%20A%20CNN%20(The%20CIFAR-10%20dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Import Libraries**

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

import torch
import numpy as np
from torchvision import datasets, models
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
from torch import optim
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ## **Loading Data**

# %%
# number of subproccesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training data to be used as validation
valid_size = 0.2

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# choose the training and test datasets
train_data = datasets.CIFAR10(root='data', train=True, download=True, transform=transform)
test_data = datasets.CIFAR10(root='data', train=True, download=True, transform=transform)

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders(combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size, num_workers=num_workers)

# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']


# print out some data stats
print('Num training images: ', len(train_data))
print('Num test images: ', len(test_data))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified
# Num training images:  50000
# Num test images:  50000

# %% [markdown]
# ## **Visualize A Batch Of Training Data**

# %%
# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image
    
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %% [markdown]
# ## **View an Image in More Detail**
#
# Here, we look at the normalized red, green, and blue (RGB) color channels as three separate, grayscale intensity images.

# %%
rgb_img = np.squeeze(images[3])
channels = ['red channel', 'green channel', 'blue channel']

fig = plt.figure(figsize = (36, 36)) 
for idx in np.arange(rgb_img.shape[0]):
    ax = fig.add_subplot(1, 3, idx + 1)
    img = rgb_img[idx]
    ax.imshow(img, cmap='gray')
    ax.set_title(channels[idx])
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            val = round(img[x][y],2) if img[x][y] !=0 else 0
            ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center', size=8,
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ## **Checking If GPU Is Available**

# %%
# Use GPU if it's available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("The ML code in this project will be trained on " + str(device))
# Out:
# The ML code in this project will be trained on cuda

# %% [markdown]
# ## **Defining The CNN Architecture**

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        #Note: It is said to keep the kernel_size at 3 until # of filters exceeds 128. Additionally, the in_channel for a CNN is either going to be 1, 3 or 4 depending on if the data is grayscale, coloured or if it has an alpha transparency channel respectively. 
        
        self.cnn_layers = nn.Sequential(nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1), 
                                        nn.BatchNorm2d(num_features=32),  #Said to accelerate training by reducing internal covariate shift (Documentation: https://pytorch.org/docs/master/generated/torch.nn.BatchNorm2d.html and Explanation: https://www.aiworkbox.com/lessons/batchnorm2d-how-to-use-the-batchnorm2d-module-in-pytorch)
                                        nn.ReLU(),
                                        nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1),
                                        nn.BatchNorm2d(num_features=32),   
                                        nn.ReLU(),
                                        nn.MaxPool2d(kernel_size=2, stride=2),
                                        nn.Dropout(0.25),
                                        nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
                                        nn.BatchNorm2d(num_features=64),
                                        nn.ReLU(),
                                        nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1),
                                        nn.BatchNorm2d(num_features=64),
                                        nn.ReLU(),
                                        nn.MaxPool2d(kernel_size=2, stride=2),
                                        nn.Dropout(0.25))
                                        #nn.AdaptiveAvgPool2d(output_size=(7, 7)))                               
                                        
        self.linear_layers = nn.Sequential(nn.Linear(64 * 8 * 8, 512),
                                        nn.ReLU(),
                                        nn.Dropout(0.5),
                                        nn.Linear(512, len(classes)),
                                        nn.Softmax(dim=1))
        
    def forward(self, x):        
        x = self.cnn_layers(x)
        # flatten image input
        # print(x.shape) In order to tell what goes into the linear layer as an input, check x.shape
        x = x.view(-1, 64 * 8 * 8)
        x = self.linear_layers(x)
        return x

# initialize the CNN
model = Net()
               
#Sending model to CPU/GPU
model.to(device);

# %% [markdown]
# ## **Specify Loss Function And Optimizer**

# %%
# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# specify optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ## **A More Detailed Look At The CNN Architecture**

# %%
# Find total parameters and trainable parameters
total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters exist in the model.')

total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} parameters will be trained.')

#Model architecture
model
# Out:
# 2,168,746 total parameters exist in the model.
# 2,168,746 parameters will be trained.
# Net(
#   (cnn_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Dropout(p=0.25, inplace=False)
#   )
#   (linear_layers): Sequential(
#     (0): Linear(in_features=4096, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=512, out_features=10, bias=True)
#     (4): Softmax(dim=1)
#   )
# )

# %% [markdown]
# ## **Testing Speed of GPU vs. CPU**

# %%
import time

for device in ['cpu', 'cuda']:

    criterion = nn.CrossEntropyLoss()
    
    # Only train the classifier parameters, feature parameters are frozen
    optimizer = optimizer = optim.SGD(model.parameters(), lr=0.01)

    model.to(device)

    for ii, (inputs, labels) in enumerate(train_loader):

        # Move input and label tensors to the GPU
        inputs, labels = inputs.to(device), labels.to(device)

        start = time.time()

        outputs = model.forward(inputs)
        loss = criterion(outputs, labels)
        #The next line of code resolved the following error: RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn
        # loss.requires_grad = True     If you don't get the error, comment out this line.
        loss.backward()
        optimizer.step()

        if ii == 3:
            break

    print(f"Device = {device}; Time per batch: {(time.time() - start) / 3:.3f} seconds")
    
## The above code tests the training speed of the GPU and the CPU 
## by training for 3 iterations and averaging the time it took to complete them.
# Out:
# Device = cpu; Time per batch: 0.034 seconds
# Device = cuda; Time per batch: 0.001 seconds

# %% [markdown]
# ## **Training The ML Model**

# %%
n_epochs = 100
epochs_no_improve = 0
n_epochs_stop = 5

# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train() # prep model for training
    for data, target in train_loader:
        # move data and target tensors to the default device
        data, target = data.to(device), target.to(device)
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        #The next line of code resolved the following error: RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn
        # loss.requires_grad = True    If you don't get the error, comment out this line.
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval() # prep model for evaluation
    for data, target in valid_loader:
        # move data and target tensors to the default device
        data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update running validation loss 
        valid_loss += loss.item()*data.size(0)
        
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_cifar.pt')
        valid_loss_min = valid_loss
        epochs_no_improve = 0
    
    else:
        epochs_no_improve += 1
        # Check early stopping condition
        if epochs_no_improve == n_epochs_stop:
            print('Early stopping!')
            break
# Out:
# Epoch: 1 	Training Loss: 2.129979 	Validation Loss: 2.034158
# Validation loss decreased (inf --> 2.034158).  Saving model ...
# Epoch: 2 	Training Loss: 1.998253 	Validation Loss: 1.959856
# Validation loss decreased (2.034158 --> 1.959856).  Saving model ...
# Epoch: 3 	Training Loss: 1.937029 	Validation Loss: 1.898778
# Validation loss decreased (1.959856 --> 1.898778).  Saving model ...
# Epoch: 4 	Training Loss: 1.897347 	Validation Loss: 1.859621
# Validation loss decreased (1.898778 --> 1.859621).  Saving model ...
# Epoch: 5 	Training Loss: 1.863267 	Validation Loss: 1.830119
# Validation loss decreased (1.859621 --> 1.830119).  Saving model ...
# Epoch: 6 	Training Loss: 1.836200 	Validation Loss: 1.810326
# Validation loss decreased (1.830119 --> 1.810326).  Saving model ...
# Epoch: 7 	Training Loss: 1.819441 	Validation Loss: 1.792348
# Validation loss decreased (1.810326 --> 1.792348).  Saving model ...
# Epoch: 8 	Training Loss: 1.803725 	Validation Loss: 1.782799
# Validation loss decreased (1.792348 --> 1.782799).  Saving model ...
# Epoch: 9 	Training Loss: 1.789102 	Validation Loss: 1.787121
# Epoch: 10 	Training Loss: 1.779932 	Validation Loss: 1.762263
# Validation loss decreased (1.782799 --> 1.762263).  Saving model ...
# Epoch: 11 	Training Loss: 1.768277 	Validation Loss: 1.766616
# Epoch: 12 	Training Loss: 1.762733 	Validation Loss: 1.747480
# Validation loss decreased (1.762263 --> 1.747480).  Saving model ...
# Epoch: 13 	Training Loss: 1.755647 	Validation Loss: 1.746550
# Validation loss decreased (1.747480 --> 1.746550).  Saving model ...
# Epoch: 14 	Training Loss: 1.748053 	Validation Loss: 1.737512
# Validation loss decreased (1.746550 --> 1.737512).  Saving model ...
# Epoch: 15 	Training Loss: 1.742094 	Validation Loss: 1.740042
# Epoch: 16 	Training Loss: 1.734348 	Validation Loss: 1.735806
# Validation loss decreased (1.737512 --> 1.735806).  Saving model ...
# Epoch: 17 	Training Loss: 1.730358 	Validation Loss: 1.730325
# Validation loss decreased (1.735806 --> 1.730325).  Saving model ...
# Epoch: 18 	Training Loss: 1.724611 	Validation Loss: 1.723233
# Validation loss decreased (1.730325 --> 1.723233).  Saving model ...
# Epoch: 19 	Training Loss: 1.718085 	Validation Loss: 1.717382
# Validation loss decreased (1.723233 --> 1.717382).  Saving model ...
# Epoch: 20 	Training Loss: 1.715622 	Validation Loss: 1.715950
# Validation loss decreased (1.717382 --> 1.715950).  Saving model ...
# Epoch: 21 	Training Loss: 1.711292 	Validation Loss: 1.723995
# Epoch: 22 	Training Loss: 1.706199 	Validation Loss: 1.712824
# Validation loss decreased (1.715950 --> 1.712824).  Saving model ...
# Epoch: 23 	Training Loss: 1.703178 	Validation Loss: 1.711122
# Validation loss decreased (1.712824 --> 1.711122).  Saving model ...
# Epoch: 24 	Training Loss: 1.698578 	Validation Loss: 1.704782
# Validation loss decreased (1.711122 --> 1.704782).  Saving model ...
# Epoch: 25 	Training Loss: 1.693398 	Validation Loss: 1.707759
# Epoch: 26 	Training Loss: 1.689964 	Validation Loss: 1.703939
# Validation loss decreased (1.704782 --> 1.703939).  Saving model ...
# Epoch: 27 	Training Loss: 1.686647 	Validation Loss: 1.698801
# Validation loss decreased (1.703939 --> 1.698801).  Saving model ...
# Epoch: 28 	Training Loss: 1.680655 	Validation Loss: 1.695133
# Validation loss decreased (1.698801 --> 1.695133).  Saving model ...
# Epoch: 29 	Training Loss: 1.679084 	Validation Loss: 1.695684
# Epoch: 30 	Training Loss: 1.674527 	Validation Loss: 1.695016
# Validation loss decreased (1.695133 --> 1.695016).  Saving model ...
# Epoch: 31 	Training Loss: 1.671323 	Validation Loss: 1.693479
# Validation loss decreased (1.695016 --> 1.693479).  Saving model ...
# Epoch: 32 	Training Loss: 1.670437 	Validation Loss: 1.686973
# Validation loss decreased (1.693479 --> 1.686973).  Saving model ...
# Epoch: 33 	Training Loss: 1.668511 	Validation Loss: 1.681805
# Validation loss decreased (1.686973 --> 1.681805).  Saving model ...
# Epoch: 34 	Training Loss: 1.661178 	Validation Loss: 1.685359
# Epoch: 35 	Training Loss: 1.659591 	Validation Loss: 1.683812
# Epoch: 36 	Training Loss: 1.657235 	Validation Loss: 1.679198
# Validation loss decreased (1.681805 --> 1.679198).  Saving model ...
# Epoch: 37 	Training Loss: 1.655051 	Validation Loss: 1.677514
# Validation loss decreased (1.679198 --> 1.677514).  Saving model ...
# Epoch: 38 	Training Loss: 1.651916 	Validation Loss: 1.676085
# Validation loss decreased (1.677514 --> 1.676085).  Saving model ...
# Epoch: 39 	Training Loss: 1.650417 	Validation Loss: 1.674828
# Validation loss decreased (1.676085 --> 1.674828).  Saving model ...
# Epoch: 40 	Training Loss: 1.647611 	Validation Loss: 1.672515
# Validation loss decreased (1.674828 --> 1.672515).  Saving model ...
# Epoch: 41 	Training Loss: 1.645526 	Validation Loss: 1.681115
# Epoch: 42 	Training Loss: 1.642461 	Validation Loss: 1.674246
# Epoch: 43 	Training Loss: 1.637508 	Validation Loss: 1.668317
# Validation loss decreased (1.672515 --> 1.668317).  Saving model ...
# Epoch: 44 	Training Loss: 1.637888 	Validation Loss: 1.667529
# Validation loss decreased (1.668317 --> 1.667529).  Saving model ...
# Epoch: 45 	Training Loss: 1.635944 	Validation Loss: 1.667986
# Epoch: 46 	Training Loss: 1.632045 	Validation Loss: 1.665203
# Validation loss decreased (1.667529 --> 1.665203).  Saving model ...
# Epoch: 47 	Training Loss: 1.630168 	Validation Loss: 1.663525
# Validation loss decreased (1.665203 --> 1.663525).  Saving model ...
# Epoch: 48 	Training Loss: 1.628463 	Validation Loss: 1.662815
# Validation loss decreased (1.663525 --> 1.662815).  Saving model ...
# Epoch: 49 	Training Loss: 1.624297 	Validation Loss: 1.665934
# Epoch: 50 	Training Loss: 1.622111 	Validation Loss: 1.666549
# Epoch: 51 	Training Loss: 1.620354 	Validation Loss: 1.659562
# Validation loss decreased (1.662815 --> 1.659562).  Saving model ...
# Epoch: 52 	Training Loss: 1.620670 	Validation Loss: 1.663808
# Epoch: 53 	Training Loss: 1.618251 	Validation Loss: 1.656358
# Validation loss decreased (1.659562 --> 1.656358).  Saving model ...
# Epoch: 54 	Training Loss: 1.614095 	Validation Loss: 1.655633
# Validation loss decreased (1.656358 --> 1.655633).  Saving model ...
# Epoch: 55 	Training Loss: 1.613348 	Validation Loss: 1.664264
# Epoch: 56 	Training Loss: 1.611497 	Validation Loss: 1.652992
# Validation loss decreased (1.655633 --> 1.652992).  Saving model ...
# Epoch: 57 	Training Loss: 1.611097 	Validation Loss: 1.654508
# Epoch: 58 	Training Loss: 1.607596 	Validation Loss: 1.661004
# Epoch: 59 	Training Loss: 1.607935 	Validation Loss: 1.658833
# Epoch: 60 	Training Loss: 1.604480 	Validation Loss: 1.649556
# Validation loss decreased (1.652992 --> 1.649556).  Saving model ...
# Epoch: 61 	Training Loss: 1.602698 	Validation Loss: 1.649787
# Epoch: 62 	Training Loss: 1.602708 	Validation Loss: 1.647427
# Validation loss decreased (1.649556 --> 1.647427).  Saving model ...
# Epoch: 63 	Training Loss: 1.599017 	Validation Loss: 1.651259
# Epoch: 64 	Training Loss: 1.597280 	Validation Loss: 1.646802
# Validation loss decreased (1.647427 --> 1.646802).  Saving model ...
# Epoch: 65 	Training Loss: 1.596686 	Validation Loss: 1.644968
# Validation loss decreased (1.646802 --> 1.644968).  Saving model ...
# Epoch: 66 	Training Loss: 1.594100 	Validation Loss: 1.646165
# Epoch: 67 	Training Loss: 1.592562 	Validation Loss: 1.653880
# Epoch: 68 	Training Loss: 1.594700 	Validation Loss: 1.642029
# Validation loss decreased (1.644968 --> 1.642029).  Saving model ...
# Epoch: 69 	Training Loss: 1.590187 	Validation Loss: 1.644864
# Epoch: 70 	Training Loss: 1.589600 	Validation Loss: 1.645077
# Epoch: 71 	Training Loss: 1.588189 	Validation Loss: 1.645433
# Epoch: 72 	Training Loss: 1.586810 	Validation Loss: 1.645253
# Epoch: 73 	Training Loss: 1.584489 	Validation Loss: 1.642321
# Early stopping!

# %% [markdown]
# ## **Load The Model With The Lowest Validation Loss**

# %%
model.load_state_dict(torch.load('model_cifar.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## **Test The Trained Network**

# %%
# initialize lists to monitor test loss and accuracy
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval() # prep model for evaluation

for data, target in test_loader:
    # move data and target tensors to the default device
    data, target = data.to(device), target.to(device)
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    # calculate test accuracy for each object class
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# calculate and print avg test loss
test_loss = test_loss/len(test_loader.sampler)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            str(i), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no more training examples left)' % (class_total[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 1.559049
#
# Test Accuracy of     0: 90% (4518/5000)
# Test Accuracy of     1: 96% (4801/5000)
# Test Accuracy of     2: 83% (4187/5000)
# Test Accuracy of     3: 83% (4193/5000)
# Test Accuracy of     4: 88% (4435/5000)
# Test Accuracy of     5: 85% (4286/5000)
# Test Accuracy of     6: 93% (4697/5000)
# Test Accuracy of     7: 92% (4618/5000)
# Test Accuracy of     8: 95% (4781/5000)
# Test Accuracy of     9: 95% (4767/5000)
#
# Test Accuracy (Overall): 90% (45283/50000)

# %% [markdown]
# ## **Visualize Sample Test Results**

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images, labels = images.to(device), labels.to(device)

#The following two lines of code avoid clipping input data by normalizing the images first
images -= images.min()
images /= images.max()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)
# prep images for display
images = images.cpu().data.numpy()

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.transpose(images[idx]), )

    ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                 color=("green" if preds[idx]==labels[idx] else "red"))
